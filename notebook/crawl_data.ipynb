# %%
# !pip install -U vnstock
# Out:
# Requirement already satisfied: vnstock in /opt/conda/lib/python3.11/site-packages (3.2.6)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from vnstock) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (from vnstock) (4.12.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from vnstock) (2.0.3)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.11/site-packages (from vnstock) (0.13.0)
# Requirement already satisfied: openpyxl in /opt/conda/lib/python3.11/site-packages (from vnstock) (3.1.2)
# Requirement already satisfied: pydantic in /opt/conda/lib/python3.11/site-packages (from vnstock) (2.12.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from vnstock) (5.9.5)
# Requirement already satisfied: fake_useragent in /opt/conda/lib/python3.11/site-packages (from vnstock) (2.2.0)
# Requirement already satisfied: vnstock_ezchart in /opt/conda/lib/python3.11/site-packages (from vnstock) (0.0.2)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from vnstock) (8.1.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from vnstock) (23.2)
# Requirement already satisfied: importlib-metadata>=1.0 in /opt/conda/lib/python3.11/site-packages (from vnstock) (6.8.0)
# Requirement already satisfied: tenacity in /opt/conda/lib/python3.11/site-packages (from vnstock) (9.1.2)
# Requirement already satisfied: vnai>=2.0.3 in /opt/conda/lib/python3.11/site-packages (from vnstock) (2.1.9)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata>=1.0->vnstock) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->vnstock) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->vnstock) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->vnstock) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->vnstock) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4->vnstock) (2.5)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.11/site-packages (from openpyxl->vnstock) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->vnstock) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->vnstock) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas->vnstock) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/lib/python3.11/site-packages (from pandas->vnstock) (1.24.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic->vnstock) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/conda/lib/python3.11/site-packages (from pydantic->vnstock) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/conda/lib/python3.11/site-packages (from pydantic->vnstock) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.11/site-packages (from pydantic->vnstock) (0.4.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in /opt/conda/lib/python3.11/site-packages (from seaborn->vnstock) (3.8.0)
# Requirement already satisfied: squarify in /opt/conda/lib/python3.11/site-packages (from vnstock_ezchart->vnstock) (0.4.4)
# Requirement already satisfied: wordcloud in /opt/conda/lib/python3.11/site-packages (from vnstock_ezchart->vnstock) (1.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->vnstock) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->vnstock) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->vnstock) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->vnstock) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->vnstock) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn->vnstock) (3.1.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->vnstock) (1.16.0)

# %%
from vnstock import Listing
from vnstock import Quote
import time
import logging
import numpy as np
listing = Listing()

# %%
# Log configurations
logging.basicConfig(
    filename='download_log.log',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    force=True
)

# %%
# List all stocks
all_stocks = listing.symbols_by_exchange()
all_stocks
# Out:
#          symbol  exchange   type                          organ_short_name  \
# 0           YTC     UPCOM  STOCK                           XNK Y tế TP.HCM
# 1           YEG       HSX  STOCK                            Tập đoàn Yeah1
# 2           YBM       HSX  STOCK                     Khoáng sản CN Yên Bái
# 3           YBC     UPCOM  STOCK             Xi măng và Khoáng sản Yên Bái
# 4           XPH     UPCOM  STOCK                           Xà phòng Hà Nội
# ...         ...       ...    ...                                       ...
# 3055  41I1F7000  DELISTED     FU                          41I1F7000 - HĐTL
# 3056  41BAG6000       HNX     FU  10-year Government Bond   Futures 062026
# 3057  41BAG3000       HNX     FU  10-year Government Bond   Futures 032026
# 3058  41B5G6000       HNX     FU  5-year Government Bond    Futures 062026
# 3059  41B5G3000       HNX     FU  5-year Government Bond    Futures 032026
#
#                                              organ_name product_grp_id
# 0     Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...            UPX
# 1                        Công ty Cổ phần Tập đoàn Yeah1            STO
# 2        Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái            STO
# 3         Công ty Cổ phần Xi măng và Khoáng sản Yên Bái            UPX
# 4                       Công ty Cổ phần Xà phòng Hà Nội            UPX
# ...                                                 ...            ...
# 3055                                   41I1F7000 - HĐTL            FIO
# 3056           10-year Government Bond   Futures 062026            FBX
# 3057           10-year Government Bond   Futures 032026            FBX
# 3058           5-year Government Bond    Futures 062026            FBX
# 3059           5-year Government Bond    Futures 032026            FBX
#
# [3060 rows x 6 columns]

# %%
# Get dataframe for Stock
stock_df = all_stocks[all_stocks['type'] == 'STOCK']
stock_df
# Out:
#      symbol exchange   type               organ_short_name  \
# 0       YTC    UPCOM  STOCK                XNK Y tế TP.HCM
# 1       YEG      HSX  STOCK                 Tập đoàn Yeah1
# 2       YBM      HSX  STOCK          Khoáng sản CN Yên Bái
# 3       YBC    UPCOM  STOCK  Xi măng và Khoáng sản Yên Bái
# 4       XPH    UPCOM  STOCK                Xà phòng Hà Nội
# ...     ...      ...    ...                            ...
# 3040    AAS    UPCOM  STOCK        Chứng khoán SmartInvest
# 3041    AAM      HSX  STOCK                Thủy sản Mekong
# 3042    AAH    UPCOM  STOCK                  Than Hợp Nhất
# 3043    AAA      HSX  STOCK            An Phát Bioplastics
# 3044    A32    UPCOM  STOCK                     Công ty 32
#
#                                              organ_name product_grp_id
# 0     Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...            UPX
# 1                        Công ty Cổ phần Tập đoàn Yeah1            STO
# 2        Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái            STO
# 3         Công ty Cổ phần Xi măng và Khoáng sản Yên Bái            UPX
# 4                       Công ty Cổ phần Xà phòng Hà Nội            UPX
# ...                                                 ...            ...
# 3040            Công ty Cổ phần Chứng khoán SmartInvest            UPX
# 3041                    Công ty Cổ Phần Thủy Sản MeKong            STO
# 3042                           Công ty Cổ phần Hợp Nhất            UPX
# 3043                  Công ty Cổ phần Nhựa An Phát Xanh            STO
# 3044                                 Công ty Cổ phần 32            UPX
#
# [1721 rows x 6 columns]

# %%
# Reset index for dataframe
stock_df = stock_df.reset_index().drop('index', axis=1)
stock_df
# Out:
#      symbol exchange   type               organ_short_name  \
# 0       YTC    UPCOM  STOCK                XNK Y tế TP.HCM
# 1       YEG      HSX  STOCK                 Tập đoàn Yeah1
# 2       YBM      HSX  STOCK          Khoáng sản CN Yên Bái
# 3       YBC    UPCOM  STOCK  Xi măng và Khoáng sản Yên Bái
# 4       XPH    UPCOM  STOCK                Xà phòng Hà Nội
# ...     ...      ...    ...                            ...
# 1716    AAS    UPCOM  STOCK        Chứng khoán SmartInvest
# 1717    AAM      HSX  STOCK                Thủy sản Mekong
# 1718    AAH    UPCOM  STOCK                  Than Hợp Nhất
# 1719    AAA      HSX  STOCK            An Phát Bioplastics
# 1720    A32    UPCOM  STOCK                     Công ty 32
#
#                                              organ_name product_grp_id
# 0     Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...            UPX
# 1                        Công ty Cổ phần Tập đoàn Yeah1            STO
# 2        Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái            STO
# 3         Công ty Cổ phần Xi măng và Khoáng sản Yên Bái            UPX
# 4                       Công ty Cổ phần Xà phòng Hà Nội            UPX
# ...                                                 ...            ...
# 1716            Công ty Cổ phần Chứng khoán SmartInvest            UPX
# 1717                    Công ty Cổ Phần Thủy Sản MeKong            STO
# 1718                           Công ty Cổ phần Hợp Nhất            UPX
# 1719                  Công ty Cổ phần Nhựa An Phát Xanh            STO
# 1720                                 Công ty Cổ phần 32            UPX
#
# [1721 rows x 6 columns]

# %%
# Write to csv
stock_df.to_csv('./data/company_info.csv')

# %%
company_name = stock_df['symbol'].to_numpy()
company_name
# Out:
# array(['YTC', 'YEG', 'YBM', ..., 'AAH', 'AAA', 'A32'], dtype=object)

# %%
company_name = stock_df['symbol'].to_numpy()
company_name
# Out:
# array(['YTC', 'YEG', 'YBM', ..., 'AAH', 'AAA', 'A32'], dtype=object)

# %%
# Number of companies to collect
len(company_name)
# Out:
# 1721

# %%
# Get stock for each company, and write each result to a CSV file
for company in company_name:
    attempts = 3
    for i in range(attempts):
        try:
            quote = Quote(symbol=company, source='VCI')
            df = quote.history(start='2012-01-01', end='2025-10-15', interval='1D')
            df.to_csv(f"./data/stock_data_{company}.csv")
            logging.info(f"Successfully downloaded and saved data for {company}.")
            
            time.sleep(1)
            break
    
        except Exception as e:
            if "VCI" in str(e) and "Vui lòng thử lại sau" in str(e):
                wait_time = 60 
                logging.warning(f"Rate limit hit for {company}. Waiting for {wait_time} seconds before retrying... ({i+1}/{attempts})")
                time.sleep(wait_time)
            else:
                logging.error(f"An unexpected error occurred for {company}: {e}")
                break

# %%
# Number of companies collected
# !ls -1 ./data | wc -l
# Out:
# 1688
